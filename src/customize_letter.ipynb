# %% [markdown]
# # Using the Cover Letter Utility
# Let's try it out!

# %% [markdown]
# Start with two schools: Goucher College and University of Minnesota. Both are applied positions.

# %%
from utility import FileData, PathData, customize_cover_letter, read_csv_to_dicts

# define the necessary data for those two schools in the csv file, read into a dict
APPLIED_APPS = read_csv_to_dicts(filepath='dicts_applied_dec31.csv')
# behavioral apps
BEHAVIORAL_APPS = read_csv_to_dicts(filepath='dicts_behavioral.csv')
# teaching apps
TEACHING_APPS = read_csv_to_dicts(filepath='dicts_teaching.csv')

# %%
print(APPLIED_APPS)
# Out:
# [{'slug': 'bi_norwegian_business_school', 'institution_name': 'BI Norwegian Business School', 'dept_name': 'Department of Economics', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'catolica_lisbon_school', 'institution_name': 'Catolica Lisbon School of Business and Economics', 'dept_name': 'Department of Economics', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'columbia_u', 'institution_name': 'Columbia University', 'dept_name': 'Department of Economics', 'job_title': 'Postdoctoral Fellow', 'letter_date': 'November 16, 2025'}, {'slug': 'eui_max_weber_pd', 'institution_name': 'European University Institute', 'dept_name': 'Max Weber Programme', 'job_title': 'Postdoctoral Fellow', 'letter_date': 'November 16, 2025'}, {'slug': 'eui_jean_monnet_pd', 'institution_name': 'European University Institute', 'dept_name': 'Jean Monnet Programme', 'job_title': 'Postdoctoral Fellow', 'letter_date': 'November 16, 2025'}, {'slug': 'mit', 'institution_name': 'MIT', 'dept_name': 'FutureTech', 'job_title': 'Postdoctoral Associate', 'letter_date': 'November 16, 2025'}, {'slug': 'ut_san_antonio', 'institution_name': 'UT San Antonio', 'dept_name': 'Department of Economics', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'paris_school_economics', 'institution_name': 'Paris School of Economics', 'dept_name': 'XXX', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'lmu_munich', 'institution_name': 'LMU Munich', 'dept_name': 'Department of Economics', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'ucd', 'institution_name': 'University College Dublin', 'dept_name': 'School of Economics', 'job_title': 'Lecturer', 'letter_date': 'November 16, 2025'}, {'slug': 'carleton_college', 'institution_name': 'Carleton College', 'dept_name': 'Department of Economics', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'halle_institute', 'institution_name': 'Halle Institute for Economics Research', 'dept_name': 'Faculty of Economics and Management', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'u_copenhagen', 'institution_name': 'University of Copenhagen', 'dept_name': 'Department of Economics', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'unsw_sydney', 'institution_name': 'Univesity of New South Wales Sydney', 'dept_name': 'School of Economics', 'job_title': 'Lecturer', 'letter_date': 'November 16, 2025'}, {'slug': 'u_manchester', 'institution_name': 'University of Manchester', 'dept_name': 'Department of Economics', 'job_title': 'Lecturer', 'letter_date': 'November 16, 2025'}, {'slug': 'berry_college_data', 'institution_name': 'Berry College', 'dept_name': 'Department of Economics and Data Analytics', 'job_title': 'Assistant Professor of Data Analytics', 'letter_date': 'November 16, 2025'}, {'slug': 'berry_college_econ', 'institution_name': 'Berry College', 'dept_name': 'Department of Economics and Data Analytics', 'job_title': 'Assistant Professor of Economics', 'letter_date': 'November 16, 2025'}, {'slug': 'cega', 'institution_name': 'Center for Effective Global Action', 'dept_name': 'XXX', 'job_title': 'Postdoctoral Scholar', 'letter_date': 'November 16, 2025'}, {'slug': 'peking_u', 'institution_name': 'Peking University', 'dept_name': 'School of Economics', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'stony_brook', 'institution_name': 'Stony Brook University', 'dept_name': 'Department of Economics', 'job_title': 'Assistant Professor', 'letter_date': 'November 16, 2025'}, {'slug': 'brown_u_ppe', 'institution_name': 'Brown University', 'dept_name': 'Center for Philosophy, Politics, and Economics', 'job_title': 'Postdoctoral Research Associate', 'letter_date': 'November 16, 2025'}, {'slug': 'cornell', 'institution_name': 'Cornell University', 'dept_n ...

# %%
import socket
print(socket.gethostname())
# Out:
# campus-110-118.ucdavis.edu

# %%
# instantiate the dataclasses
paths = PathData()
names = FileData()

# %% [markdown]
# Replace the applied applications cover letters.

# %%
for app in APPLIED_APPS:
    # make a copy of the original dict and remove the slug to feed into the function
    replace_dict = app.copy()
    replace_dict.pop('slug')

    customize_cover_letter(
        template_name=names.applied_template_name,
        template_path=paths.template_path,
        app_path=paths.app_path,
        slug=app['slug'],
        replace_dict=replace_dict
    )

# %%
for app in BEHAVIORAL_APPS:
    # make a copy of the original dict and remove the slug to feed into the function
    replace_dict = app.copy()
    replace_dict.pop('slug')

    customize_cover_letter(
        template_name=names.behavioral_template_name,
        template_path=paths.template_path,
        app_path=paths.app_path,
        slug=app['slug'],
        replace_dict=replace_dict
    )

# %%
for app in TEACHING_APPS:
    # make a copy of the original dict and remove the slug to feed into the function
    replace_dict = app.copy()
    replace_dict.pop('slug')

    customize_cover_letter(
        template_name=names.teaching_template_name,
        template_path=paths.template_path,
        app_path=paths.app_path,
        slug=app['slug'],
        replace_dict=replace_dict
    )
